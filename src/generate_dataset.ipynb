# %%
import numpy as np
from PIL import Image

from utils import generate_image_and_labels

# %%
img, labels = generate_image_and_labels()

print(labels)
# Out:
# [{'class': 'rectangle', 'bbox': [13, 57, 47, 89], 'angle': 6.391987216025807, 'color': (217, 145, 123)}, {'class': 'rectangle', 'bbox': [64, 63, 100, 101], 'angle': 10.361137463220555, 'color': (122, 184, 51)}]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
